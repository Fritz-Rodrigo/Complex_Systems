# %% [markdown]
# # Heavy Metal Umlaut
#
#
# Example using unicode strings as graph labels.
#
# Also shows creative use of the Heavy Metal Umlaut:
# https://en.wikipedia.org/wiki/Heavy_metal_umlaut

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy

hd = "H" + chr(252) + "sker D" + chr(252)
mh = "Mot" + chr(246) + "rhead"
mc = "M" + chr(246) + "tley Cr" + chr(252) + "e"
st = "Sp" + chr(305) + "n" + chr(776) + "al Tap"
q = "Queensr" + chr(255) + "che"
boc = "Blue " + chr(214) + "yster Cult"
dt = "Deatht" + chr(246) + "ngue"

G = nx.Graph()
G.add_edge(hd, mh)
G.add_edge(mc, st)
G.add_edge(boc, mc)
G.add_edge(boc, dt)
G.add_edge(st, dt)
G.add_edge(q, st)
G.add_edge(dt, mh)
G.add_edge(st, mh)

# write in UTF-8 encoding
fh = open("edgelist.utf-8", "wb")
nx.write_multiline_adjlist(G, fh, delimiter="\t", encoding="utf-8")

# read and store in UTF-8
fh = open("edgelist.utf-8", "rb")
H = nx.read_multiline_adjlist(fh, delimiter="\t", encoding="utf-8")

node_sizes = []
edge_width = []
for i in G:
    node_sizes.append(200*len(G.edges(i)))
    edge_width.append(2*len(G.edges(i)))
    
    
# for n in G.nodes():
#     if n not in H:
#         print(False)
# print(list(G.nodes()))

plt.figure(figsize=(12,8))
plt.xlim(-1.2,1.2)
plt.ylim(-1.2,1.2)
pos = nx.spring_layout(G)
nx.draw(G, pos, node_size = node_sizes, width = edge_width, with_labels=False)
for p in pos:  # raise text positions
    pos[p][1] += 0.1
nx.draw_networkx_labels(G, pos, font_size=12)
plt.show()

# %%
for i in G:
    print(len(G.edges(i)), G.edges(i))
# Out:
# 1 [('Hüsker Dü', 'Motörhead')]
# 3 [('Motörhead', 'Hüsker Dü'), ('Motörhead', 'Deathtöngue'), ('Motörhead', 'Spın̈al Tap')]
# 2 [('Mötley Crüe', 'Spın̈al Tap'), ('Mötley Crüe', 'Blue Öyster Cult')]
# 5 [('Spın̈al Tap', 'Mötley Crüe'), ('Spın̈al Tap', 'Deathtöngue'), ('Spın̈al Tap', 'Queensrÿche'), ('Spın̈al Tap', 'Motörhead'), ('Spın̈al Tap', 'Megadeth')]
# 2 [('Blue Öyster Cult', 'Mötley Crüe'), ('Blue Öyster Cult', 'Deathtöngue')]
# 3 [('Deathtöngue', 'Blue Öyster Cult'), ('Deathtöngue', 'Spın̈al Tap'), ('Deathtöngue', 'Motörhead')]
# 1 [('Queensrÿche', 'Spın̈al Tap')]
# 1 [('Megadeth', 'Spın̈al Tap')]
